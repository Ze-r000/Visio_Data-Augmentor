# %%
import Augmentor

# %%
p = Augmentor.Pipeline(r"c:\Users\AI\Desktop\My-Dataset\1. First 40")

p.flip_left_right(probability=1)
p.shear(probability=1, max_shear_left=25, max_shear_right=10)
p.zoom(probability=1, min_factor=1, max_factor=2)
p.flip_left_right(probability=1)
p.random_brightness(probability=1, min_factor=0.5, max_factor=1.4)
p.skew(probability=1, magnitude=0.8)
p.random_contrast(probability=1, min_factor=0.5, max_factor=1.8)
p.flip_left_right(probability=1)
p.resize(probability=1, width=500, height=550, resample_filter='BICUBIC')

p.sample(100)
# Out:
# Initialised with 40 image(s) found.
# Output directory set to c:\Users\AI\Desktop\My-Dataset\1. First 40\output.
# Executing Pipeline:   0%|          | 0/100 [00:00<?, ? Samples/s]c:\Users\AI\miniconda3\envs\data_augmentation\lib\site-packages\PIL\Image.py:3182: DecompressionBombWarning: Image size (100452000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# c:\Users\AI\miniconda3\envs\data_augmentation\lib\site-packages\PIL\Image.py:3182: DecompressionBombWarning: Image size (105480000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Processing <PIL.Image.Image image mode=RGB size=500x550 at 0x19E89A88070>:   3%|▎         | 3/100 [02:07<1:26:33, 53.54s/ Samples] c:\Users\AI\miniconda3\envs\data_augmentation\lib\site-packages\PIL\Image.py:3182: DecompressionBombWarning: Image size (96615000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
# ...

# %%
help(p.flip_left_right)
